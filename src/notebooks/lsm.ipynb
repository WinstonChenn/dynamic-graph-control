# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
seq = [np.random.uniform(low=-np.pi, high=np.pi, size=1)[0]]
for i in range(100):
    seq.append(np.pi*np.sin(seq[-1]))
plt.plot(seq, marker="o")
